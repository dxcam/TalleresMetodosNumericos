# %% [markdown]
# <h1 align="center" style="color: pink;">TAREA 10.5 UNIDAD</h1>

# %% [markdown]
# **Nombre:** Camila Caicedo
#
# **Curso:** GR1CC
#
# **Fecha de entrega:** 07/01/2026

# %% [markdown]
# **Enlace al repositorio:** https://github.com/dxcam/TalleresMetodosNumericos.git

# %% [markdown]
# <h3 align="center" style="color: pink;">MATRIZ INVERSA - DESCOMPOSICIÓN LU</h3>

# %% [markdown]
# **Para las siguientes matrices:**
# - calcule la matriz inversa con el método de Gauss-Jordan
# - calcule la descomposición LU.

# %% [markdown]
# # Ejercicio 1

# %% [markdown]
# <div align="center">
#   <img src=".\img\E1.jpg" width="600" alt="-">
# </div>

# %% [markdown]
# # Ejercicio 2

# %% [markdown]
# <div align="center">
#   <img src=".\img\E2.jpg" width="600" alt="-">
# </div>

# %% [markdown]
# # Ejercicio 3

# %% [markdown]
# <div align="center">
#   <img src=".\img\E3.jpg" width="600" alt="-">
# </div>

# %% [markdown]
# # Ejercicio 4

# %% [markdown]
# <<div align="center">
#   <img src=".\img\E1.jpg" width="600" alt="-">
# </div>
#
# <div align="center">
#   <img src=".\img\E4.2.jpg" width="600" alt="-">
# </div>
